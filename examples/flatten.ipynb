# %%
#import numpy as np
from sklearn.datasets import load_diabetes

import sys
sys.path.append('..')
from korr import pearson, flatten

# %% [markdown]
# Load demo dataset

# %%
X = load_diabetes().data

# %% [markdown]
# Compute correlations

# %%
rho, pval = pearson(X)

# %% [markdown]
# Flatten the matrices into a table

# %%
tab = flatten(rho, pval)
tab
# Out:
#     i  j       cor           pval
# 30  4  5  0.896663  8.341807e-158
# 39  6  7 -0.738493   2.484665e-77
# 36  5  7  0.659817   1.410336e-56
# 42  7  8  0.617857   6.981615e-48
# 32  4  7  0.542207   3.819722e-35
# 33  4  8  0.515501   2.248539e-31
# 44  8  9  0.464670   4.664159e-25
# 22  2  8  0.446159   5.234796e-23
# 43  7  9  0.417212   4.820011e-20
# 21  2  7  0.413807   1.031196e-19
# 40  6  8 -0.398577   2.786183e-18
# 17  2  3  0.395415   5.408803e-18
# 28  3  8  0.393478   8.092715e-18
# 29  3  9  0.390429   1.517659e-17
# 23  2  9  0.388680   2.170657e-17
# 13  1  6 -0.379090   1.486840e-16
# 20  2  6 -0.366811   1.594491e-15
# 2   0  3  0.335427   4.393220e-13
# 14  1  7  0.332115   7.667030e-13
# 34  4  9  0.325717   2.206445e-12
# 37  5  8  0.318353   7.224170e-12
# 8   0  9  0.301731   9.347961e-11
# 38  5  9  0.290600   4.751211e-10
# 41  6  9 -0.273697   4.917718e-09
# 7   0  8  0.270777   7.248756e-09
# 19  2  5  0.261170   2.514909e-08
# 3   0  4  0.260061   2.894154e-08
# 27  3  7  0.257653   3.917060e-08
# 18  2  4  0.249777   1.032152e-07
# 24  3  4  0.242470   2.464183e-07
# 10  1  3  0.241013   2.921301e-07
# 4   0  5  0.219243   3.271391e-06
# 16  1  9  0.208133   1.025312e-05
# 6   0  7  0.203841   1.568788e-05
# 35  5  6 -0.196455   3.194540e-05
# 25  3  5  0.185558   8.701324e-05
# 1   0  2  0.185085   9.076792e-05
# 26  3  6 -0.178761   1.580476e-04
# 0   0  1  0.173737   2.423425e-04
# 15  1  8  0.149918   1.573408e-03
# 12  1  5  0.142637   2.649987e-03
# 9   1  2  0.088161   6.404796e-02
# 5   0  6 -0.075181   1.144857e-01
# 31  4  6  0.051519   2.797935e-01
# 11  1  4  0.035277   4.594318e-01

# %%
tab = flatten(rho, pval, sortby="pval")
tab
# Out:
#     i  j       cor           pval
# 30  4  5  0.896663  8.341807e-158
# 39  6  7 -0.738493   2.484665e-77
# 36  5  7  0.659817   1.410336e-56
# 42  7  8  0.617857   6.981615e-48
# 32  4  7  0.542207   3.819722e-35
# 33  4  8  0.515501   2.248539e-31
# 44  8  9  0.464670   4.664159e-25
# 22  2  8  0.446159   5.234796e-23
# 43  7  9  0.417212   4.820011e-20
# 21  2  7  0.413807   1.031196e-19
# 40  6  8 -0.398577   2.786183e-18
# 17  2  3  0.395415   5.408803e-18
# 28  3  8  0.393478   8.092715e-18
# 29  3  9  0.390429   1.517659e-17
# 23  2  9  0.388680   2.170657e-17
# 13  1  6 -0.379090   1.486840e-16
# 20  2  6 -0.366811   1.594491e-15
# 2   0  3  0.335427   4.393220e-13
# 14  1  7  0.332115   7.667030e-13
# 34  4  9  0.325717   2.206445e-12
# 37  5  8  0.318353   7.224170e-12
# 8   0  9  0.301731   9.347961e-11
# 38  5  9  0.290600   4.751211e-10
# 41  6  9 -0.273697   4.917718e-09
# 7   0  8  0.270777   7.248756e-09
# 19  2  5  0.261170   2.514909e-08
# 3   0  4  0.260061   2.894154e-08
# 27  3  7  0.257653   3.917060e-08
# 18  2  4  0.249777   1.032152e-07
# 24  3  4  0.242470   2.464183e-07
# 10  1  3  0.241013   2.921301e-07
# 4   0  5  0.219243   3.271391e-06
# 16  1  9  0.208133   1.025312e-05
# 6   0  7  0.203841   1.568788e-05
# 35  5  6 -0.196455   3.194540e-05
# 25  3  5  0.185558   8.701324e-05
# 1   0  2  0.185085   9.076792e-05
# 26  3  6 -0.178761   1.580476e-04
# 0   0  1  0.173737   2.423425e-04
# 15  1  8  0.149918   1.573408e-03
# 12  1  5  0.142637   2.649987e-03
# 9   1  2  0.088161   6.404796e-02
# 5   0  6 -0.075181   1.144857e-01
# 31  4  6  0.051519   2.797935e-01
# 11  1  4  0.035277   4.594318e-01
